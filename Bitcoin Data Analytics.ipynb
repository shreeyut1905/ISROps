# %%
# !kaggle datasets download -d subho117/bitcoin-price-prediction-using-machine-learning
# Out:
# Dataset URL: https://www.kaggle.com/datasets/subho117/bitcoin-price-prediction-using-machine-learning
# License(s): MIT
# Downloading bitcoin-price-prediction-using-machine-learning.zip to /content
# 100% 75.9k/75.9k [00:00<00:00, 501kB/s]
# 100% 75.9k/75.9k [00:00<00:00, 500kB/s]

# %%
# !unzip /content/bitcoin-price-prediction-using-machine-learning.zip
# Out:
# Archive:  /content/bitcoin-price-prediction-using-machine-learning.zip
#   inflating: bitcoin.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/bitcoin.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   2713.000000   2713.000000   2713.000000   2713.000000   2713.000000
# mean   11311.041069  11614.292482  10975.555057  11323.914637  11323.914637
# std    16106.428891  16537.390649  15608.572560  16110.365010  16110.365010
# min      176.897003    211.731003    171.509995    178.102997    178.102997
# 25%      606.396973    609.260986    604.109985    606.718994    606.718994
# 50%     6301.569824   6434.617676   6214.220215   6317.609863   6317.609863
# 75%    10452.399414  10762.644531  10202.387695  10462.259766  10462.259766
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125
#
#              Volume
# count  2.713000e+03
# mean   1.470462e+10
# std    2.001627e+10
# min    5.914570e+06
# 25%    7.991080e+07
# 50%    5.098183e+09
# 75%    2.456992e+10
# max    3.509679e+11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2713 entries, 0 to 2712
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2713 non-null   object
#  1   Open       2713 non-null   float64
#  2   High       2713 non-null   float64
#  3   Low        2713 non-null   float64
#  4   Close      2713 non-null   float64
#  5   Adj Close  2713 non-null   float64
#  6   Volume     2713 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 148.5+ KB

# %%
plt.figure(figsize=(15,10))
plt.plot(df["Close"])
plt.title('Bitcoin Price')
plt.xlabel('Date')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
df[df['Close'] == df['Adj Close']].shape, df.shape
# Out:
# ((2713, 7), (2713, 7))

# %%
df = df.drop(['Adj Close'], axis=1)

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
features = ["Open","High","Low","Close"]
plt.subplots(figsize=(20,10))
for i,col in enumerate(features):
  plt.subplot(2,2,i+1)
  sb.distplot(df[col])
plt.show()

# %%
features = ["Open","High","Low","Close"]
plt.subplots(figsize=(20,10))
for i,col in enumerate(features):
  plt.subplot(2,2,i+1)
  sb.boxplot(df[col])
plt.show()

# %%
splitted = df["Date"].str.split("-",expand=True)
df['year'] = splitted[0].astype('int')
df['month'] = splitted[1].astype('int')
df['day'] = splitted[2].astype('int')

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close    Volume  year  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  21056800  2014
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  34483200  2014
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  37919700  2014
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  36863600  2014
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  26580100  2014
#
#    month  day
# 0      9   17
# 1      9   18
# 2      9   19
# 3      9   20
# 4      9   21

# %%
data_grouped =
